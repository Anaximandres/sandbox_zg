# %%
from read_and_write.csv_handler import CSVHandler
from S1.ReducedBatchCollection import S1ReducedCollection
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from read_and_write.csv_handler import CSVHandler
#       2 from S1.ReducedBatchCollection import S1ReducedCollection
#
# File c:\Users\zacha\projects\derive_row_direction\read_and_write\csv_handler.py:2
#       1 import os
# ----> 2 from S1.MutableCollection import S1MutableCollection
#       3 from S1.ReducedBatchCollection import S1ReducedCollection
#       4 from FeatureManipulation import FeatureCollectionUtils
#
# File c:\Users\zacha\projects\derive_row_direction\S1\MutableCollection.py:10
#       8 import FeatureManipulation.FeatureCollectionUtils as FeatureCollectionUtils
#       9 from typing import Union, List, Literal
# ---> 10 from S1.ReducedCollection import S1ReducedCollection
#      13 if TYPE_CHECKING:
#      14         from S1.ImmutableCollection import S1ImmutableCollection
#
# ...

# %%
my_reader = CSVHandler('tests')

# %%
my_reader.get_relative_orbits()
# Out:
# {37}

# %%
my_reduced_collection = my_reader.read_to_a_reduced_collection('S1_RO_37_Pass_DES_Year_2025_01of01.csv')

# %%
print(my_reduced_collection)
# Out:
# Reduced Collection of 'S1_RO_37_Pass_DES_Year_2025_01of01'

# %%
my_dict = my_reduced_collection.create_long_variable_dfs()

# %%
my_dict
# Out:
# {'VH_stdDev':     OID        timestamp  VH_stdDev
#  0     5  20250107T055058   1.752630
#  1     3  20250107T055058   1.981261
#  2     4  20250107T055058   1.855848
#  3     1  20250107T055058   1.747693
#  0     5  20250119T055057   1.825520
#  ..  ...              ...        ...
#  3     1  20251215T054929   1.843207
#  0     5  20251227T054928   1.861169
#  1     3  20251227T054928   2.828850
#  2     4  20251227T054928   2.331963
#  3     1  20251227T054928   2.223907
#
#  [196 rows x 3 columns],
#  'VH_mean':     OID        timestamp    VH_mean
#  0     5  20250107T055058 -16.151235
#  1     3  20250107T055058 -14.415536
#  2     4  20250107T055058 -16.865512
#  3     1  20250107T055058 -14.767352
#  0     5  20250119T055057 -17.388203
#  ..  ...              ...        ...
#  3     1  20251215T054929 -18.512166
#  0     5  20251227T054928 -21.559676
#  1     3  20251227T054928 -21.047078
#  2     4  20251227T054928 -21.729882
#  3     1  20251227T054928 -23.276986
#
# ...

# %%
import re
_BATCH_SUFFIX_PATTERN = re.compile(r"^(\d+)of(\d+)$")
type(_BATCH_SUFFIX_PATTERN)
# Out:
# re.Pattern
